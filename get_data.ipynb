# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("prathamtripathi/drug-classification", output_dir='./data')

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.68k/1.68k [00:00<00:00, 648kB/s]
# Extracting files...
# Path to dataset files: ./data
